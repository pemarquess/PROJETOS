# %% [markdown]
# # Aula 11
# Listas em Python

# %% [markdown]
# # Aula 12
# FOR/ELSE em Python

# %% [markdown]
# # Aula 13
# Split, Join e Enumerate em Python

# %% [markdown]
# # Aula 14
# Desempacotamento se listas em Python

# %% [markdown]
# # Aula 15
# Operação ternária em Python
